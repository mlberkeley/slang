# %%
# Import parsed data

import numpy as np
import random
import os
import pickle

from story_parse import Parser
from gradcheck import gradcheck_naive

params = { 'load':False,
        'load_idx':0,
         'dir':'../bstm_models/v4/model',
        'seq_len':25,
        'vocab_size':20002,
        'word_dims':2048}
parser = Parser(["../data/sentence5.csv"], "csv", params['vocab_size'] - 2, params['seq_len'])
# Out:
# Reading book: ../data/sentence5.csv
# Cleaning sentences...
# Finished Cleaning
# Cleaning Data Complete
# Creating Dictionaries...
# Created dictionaries
# Creating all sentences...
# Done creating sentences
# Collecting all stories...
# Done collecting stories
# Words: 2562529
# Unique words: 20002
# Sentences: 262420
# Data initialized

# %%
# Instantiate Dataset (basically a Parser with 2 additional functions, sampleTokenIdx and getRandomContext)
from word2vec import *

dataset = Dataset(parser)
print(dataset.sampleTokenIdx())
print(dataset.getRandomContext(3))
# Out:
# 16677
# ('showed', ['worker', 'and', 'always', 'up', 'to', 'work'])

# %%
# Perform sgd. Output will be in saved_params
from sgd import *

nWords = len(parser.encode_dict)
dimVectors = 10
tokens = parser.encode_dict

# Context size
C = 5

# Reset the random seed to make sure that everyone gets the same results
wordVectors = np.concatenate(((np.random.rand(nWords, dimVectors) - .5) / \
	dimVectors, np.zeros((nWords, dimVectors))), axis=0)
wordVectors0 = sgd(
    lambda vec: word2vec_sgd_wrapper(skipgram, tokens, vec, dataset, C, 
    	negSamplingCostAndGradient), 
    wordVectors, 0.3, 40000, None, True, PRINT_EVERY=1000)
print("sanity check: cost at convergence should be around or below 10")
# Out:
# sanity check: cost at convergence should be around or below 10

# %%
cost, _ = word2vec_sgd_wrapper(skipgram, tokens, wordVectors0, dataset, C, negSamplingCostAndGradient)
print("Cost: {0}".format(cost))
# Out:
# Cost is 3.4893120813880274

# %%
import pickle

d = {'word_to_index_dict': tokens, 'index_to_vec_array': wordVectors0}

with open('w2v_10d.pickle', 'wb') as handle:
    pickle.dump(d, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('w2v_10d.pickle', 'rb') as handle:
    b = pickle.load(handle)

b
# Out:
# {'index_to_vec_array': array([[  1.50726228e+00,   1.32723395e-01,  -6.22676794e-01, ...,
#           -5.09137590e+00,   5.76082192e-01,   2.58693325e-02],
#         [  1.21076926e-01,   2.62592344e-02,  -4.59929677e-02, ...,
#           -1.33916362e-01,  -4.17179182e-02,   9.85271067e-02],
#         [  1.49922796e+00,  -2.81579811e-01,  -5.50709706e-02, ...,
#            8.29218061e-03,  -4.82811373e-01,   1.68131569e+00],
#         ...,
#         [  1.16280214e-02,   5.00596743e-03,  -6.89530128e-03, ...,
#           -1.10879314e-02,   1.82273073e-03,   8.20661102e-03],
#         [  6.03835119e-05,   2.63604741e-04,   1.33248657e-04, ...,
#           -1.41081646e-04,   7.79318281e-05,  -6.66736404e-05],
#         [ -1.34626743e-04,  -1.68474217e-04,   1.80581120e-04, ...,
#           -6.10997519e-05,  -1.52451095e-04,   1.10635895e-04]]),
#  'word_to_index_dict': {'preparedness': 13338,
#   'amish': 910,
#   'caricatures': 2924,
#   'omaha': 12053,
#   'hinted': 8270,
#   'hr': 8495,
#   'telemarketer': 17574,
#   'chatted': 3204,
#   'latoya': 9921,
#   'puked': 13626,
#   'overate': 12249,
#   'banning': 1615,
#   'frame': 7005,
#   'exposure': 6283,
#   'weak': 19199,
#   'pour': 13247,
#   'underweight': 18541,
#   'annabel': 985,
#   'eulogy': 6108,
#   'considers': 3981,
#   'haiti': 7901,
#   'radiator': 13812,
#   '4am': 263,
#   'rule': 14887,
#   'mottled': 11397,
#   'hospitals': 8442,
#   'mahmoud': 10562,
#   'ima': 8665,
#   'seemed': 15369,
#   'accepts': 432,
#   'colder': 3671,
#   'lapse': 9887,
#   'entangled': 5981,
#   'jenkins': 9269,
#   'bronze': 2503,
#   'leftovers': 10038,
#   'cole': 3673,
#   'chromebook': 3377,
#   'cluster': 3603,
#   "'it": 9,
#   'relative': 14247,
#   'grown-up': 7765,
#   'mound': 11398,
#   'cursing': 4505,
#   'lot': 10394,
#   'joann': 9335,
#   'whale-watching': 19302,
#   'optimistic': 12116,
#   'raised': 13855,
#   'vulnerable': 19032,
#   'thousand': 17772,
#   'programmed': 13491,
#   'binding': 1996,
#   'card': 2900,
#   'publish': 13609,
#   'reality': 13988,
#   'wagged': 19050,
#   'grabs': 7577,
#   'fair': 6363,
#   'beakers': 1736,
#   'farts': 6420,
#   'horny': 8419,
#   'cue': 4466,
#   'quenched': 13739,
#   'rumface': 14897,
#   'wither': 19571,
#   'transgender': 18148,
#   'courage': 4224,
#   'spaghetti': 16356,
#   '5k': 285,
#   'dory': 5398,
#   'howls': 8493,
#   'finn': 6649,
#   'bridge': 2451,
#   'dictionary': 5046,
#   'dissatisfied': 5245,
#   'europe': 6110,
#   'groaning': 7731,
#   'illnesses': 8659,
#   'maniacally': 10641,
#   'cookies': 4097,
#   'zola': 19975,
#   'koji': 9749,
#   'dam': 4561,
#   '1963.': 97,
#   'skateboarder': 15905,
#   '2002.': 161,
#   'drum': 5550,
#   'awfully': 1468,
#   'bombs': 2207,
#   'coke': 3664,
#   'accomplishing': 452,
#   '46': 259,
#   'juvenile': 9487,
#   'arrival': 1217,
#   'computer': 3860,
#   'cheerleader': 3244,
#   'merry': 10996,
#   'ego': 5756,
#   'travelled': 18178,
#   'sweets': 17271,
#   'exhaust': 6212,
#   'toppings': 18013,
#   'harriett': 8022,
#   'hotel': 8457,
#   'festival': 6545,
#   'backside': 1515,
#   'stripper': 16919,
#   'allison': 829,
#   'rehearsing': 14220,
#   'desperate': 4950,
#   'petitioned': 12772,
#   'classmates': 3479,
#   'weighing': 19255,
#   'terminal': 17631,
#   'nightstand': 11759,
#   'caves': 3062,
#   'brand': 2365,
#   'accord': 455,
#   'increasing': 8766,
#   'rafters': 13823,
#   'pests': 12762,
#   'babysitting': 1494,
#   'gemstone': 7315,
#   'toni': 17987,
#   'always': 872,
#   'existed': 6222,
#   'features': 6482,
#   'leaked': 9990,
#   'alphabetically': 852,
#   'goodnight': 7536,
#   'knowingly': 9737,
#   'princesses': 13416,
#   'prettiest': 13383,
#   'circuits': 3423,
#   'hangs': 7976,
#   'disoriented': 5219,
#   'acres': 505,
#   'atmosphere': 1336,
#   'jake': 9176,
#   'industrial': 8804,
#   'essentially': 6083,
#   'unresponsive': 18647,
#   'ill.': 8653,
#   'fantastic': 6399,
#   'poms': 13137,
#   'flights': 6771,
#   'boredom': 2255,
#   'mummy': 11470,
#   'leaped': 10002,
#   'jealous': 9242,
#   'jeanine': 9246,
#   'eastern': 5685,
#   'jimmie': 9321,
#   'mickey': 11053,
#   'raising': 13858,
#   'acquisition': 502,
#   'shoplifted': 15685,
#   'leaders': 9978,
#   'elderly': 5780,
#   'katie': 9543,
#   'leakage': 9989,
#   'fluffed': 6829,
#   'littering': 10266,
#   'bicycle': 1956,
#   'corn': 4143,
#   'chunky': 3391,
#   'cakes': 2752,
#   'spotify': 16508,
#   'equipment': 6035,
#   'rocking': 14740,
#   'results': 14511,
#   'barked': 1644,
#   'subsequently': 17014,
#   'bled': 2085,
#   'deter': 4979,
#   'plead': 13010,
#   'minimal': 11142,
#   'arms': 1198,
#   'panicking': 12421,
#   'spying': 16558,
#   'lil': 10182,
#   'mischievous': 11176,
#   'views': 18925,
#   'lina': 10209,
#   'daredevil': 4612,
#   'overpaid': 12285,
#   'roomie': 14796,
#   'happily': 7991,
#   'ticks': 17840,
#   'daring': 4615,
#   'johnston': 9366,
#   'tarts': 17485,
#   'realise': 13985,
#   'injuring': 8878,
#   'friends': 7088,
#   'jaime': 9175,
#   'charlie': 3186,
#   'little': 10267,
#   'staged': 16612,
#   'frustrated': 7130,
#   'student': 16953,
#   'inventions': 9049,
#   'sources': 16340,
#   'crepes': 4344,
#   'apparel': 1084,
#   'toyota': 18090,
#   'endless': 5931,
#   'caleb': 2759,
#   '31': 229,
#   'dominique': 5357,
#   'highs': 8244,
#   'tougher': 18057,
#   'turnout': 18371,
#   'saturdays': 15078,
#   'kicks': 9629,
#   'freestyle': 7056,
#   'mess': 11002,
#   'criticized': 4370,
#   'deanna': 4694,
#   'sony': 16296,
#   'sunblock': 17090,
#   'bottom': 2285,
#   'violence': 18951,
#   'amazingly': 885,
#   'perez': 12698,
#   'gadgets': 7210,
#   'wars': 19143,
#   'eileen': 5766,
#   'polly': 13128,
#   'honorary': 8382,
#   'drano': 5467,
#   'tokyo': 17964,
#   'bc': 1722,
#   'hopeless': 8402,
#   'deftly': 4798,
#   'agri': 699,
#   'amazement': 883,
#   'streaming': 16882,
#   'cosmetologist': 4175,
#   'myron': 11521,
#   'muscles': 11485,
#   'tricking': 18230,
#   'recreate': 14094,
#   'habits': 7872,
#   'alas': 754,
#   'cuter': 4529,
#   'wildlife': 19448,
#   'dance': 4577,
#   'resembling': 14436,
#   'clapped': 3456,
#   'kenna': 9593,
#   'luther': 10489,
#   'lewis': 10113,
#   'drawing': 5476,
#   'state': 16690,
#   'scores': 15210,
#   'ranking': 13899,
#   'reentered': 14134,
#   'slightly': 16014,
#   'decisions': 4733,
#   'leonardo': 10077,
#   'colic': 3675,
#   'decorations': 4752,
#   'traditions': 18113,
#   'bush': 2669,
#   'rides': 14626,
#   'siegfried': 15791,
#   'crap': 4293,
#   'bakes': 1556,
#   'lousy': 10414,
#   'tamika': 17432,
#   'drunkenly': 5559,
#   'whites': 19382,
#   'koa': 9745,
#   'mellow': 10936,
#   'teach': 17521,
#   'garry': 7267,
#   'crunk': 4436,
#   'jamillah': 9195,
#   'contraption': 4053,
#   'currently': 4501,
#   'benefits': 1881,
#   'linda': 10211,
#   'fires': 6664,
#   'annika': 992,
#   'heaven': 8127,
#   'dyes': 5636,
#   'gemma': 7313,
#   'gertrude': 7370,
#   'grad': 7584,
#   'five': 6691,
#   'pippa': 12910,
#   'luck': 10446,
#   'productive': 13473,
#   'marcie': 10686,
#   'convince': 4084,
#   'fumbled': 7151,
#   'broad': 2486,
#   'quietly': 13758,
#   'revere': 14559,
#   'stair': 16620,
#   'caesar': 2738,
#   'elevated': 5807,
#   'intolerant': 9025,
#   'brokenhearted': 2497,
#   'tastings': 17498,
#   'nut': 11898,
#   'does': 5325,
#   'brayden': 2389,
#   'physician': 12824,
#   'wowed': 19700,
#   'agency': 674,
#   'bulging': 2593,
#   'township': 18084,
#   'belts': 1865,
#   'actors': 525,
#   'hireability': 8280,
#   'stuart': 16946,
#   'live': 10270,
#   '800': 324,
#   'shortcut': 15699,
#   'snowmobile': 16195,
#   'appreciation': 1126,
#   'clown': 3586,
#   'auto': 1417,
#   'propose': 13534,
#   'modern': 11262,
#   'drapes': 5469,
#   'golfing': 7525,
#   'tours': 18069,
#   'carlie': 2933,
#   'potty': 13239,
#   'bluegill': 2149,
#   'levon': 10110,
#   'shared': 15561,
#   'bookshop': 2235,
#   'griped': 7726,
#   'comes': 3746,
#   'e-cigarettes': 5641,
#   '49': 262,
#   'bulbs': 2592,
#   'informs': 8852,
#   'wizards': 19586,
#   'elli': 5830,
#   'hoppy': 8409,
#   'photos': 12817,
#   'olive': 12040,
#   'extension': 6292,
#   'giselle': 7429,
#   'replies': 14385,
#   'temperatures': 17593,
#   'broadway': 2489,
#   'crotch': 4403,
#   'bellos': 1853,
#   'pascal': 12496,
#   'bosses': 2267,
#   'band': 1588,
#   'he': 8075,
#   'exuberant': 6312,
#   'imagining': 8674,
#   'cecilia': 3077,
#   'both': 2276,
#   'hoverboard': 8484,
#   'exhilarated': 6218,
#   'patti': 12554,
#   'blender': 2092,
#   'cities': 3432,
#   'disgust': 5186,
#   'shills': 15638,
#   'non': 11808,
#   'yankees': 19805,
#   'must': 11501,
#   'wonderfully': 19611,
#   'short': 15695,
#   'reveals': 14554,
#   'maryann': 10777,
#   'suit': 17069,
#   'amusing': 928,
#   'anna': 984,
#   'readily': 13979,
#   '55': 281,
#   'calendar': 2760,
#   'widowed': 19417,
#   'dumpster': 5599,
#   'airs': 732,
#   'pressured': 13372,
#   'leased': 10011,
#   'tumor': 18344,
#   'gas': 7271,
#   'caden': 2735,
#   'religious': 14273,
#   'bumpy': 2621,
#   'memorable': 10952,
#   'tow': 18070,
#   'autographs': 1421,
#   'lazlo': 9972,
#   'heaviest': 8130,
#   'beating': 1758,
#   'investors': 9064,
#   'fact': 6347,
#   'mit': 11217,
#   'forlorn': 6946,
#   'waters': 19179,
#   'volatile': 19002,
#   'reminding': 14306,
#   'see': 15358,
#   'duet': 5581,
#   'eager': 5647,
#   'cologne': 3708,
#   'salad': 14983,
#   'randomly': 13891,
#   'jeanie': 9245,
#   '18th': 92,
#   'workouts': 19663,
#   'skylar': 15954,
#   'finishing': 6648,
#   'busting': 2682,
#   'exit': 6224,
#   'paxton': 12578,
#   'embarrassment': 5863,
#   'butterflies': 2694,
#   'appointment': 1118,
#   'enough': 5971,
#   'prank': 13277,
#   'sordid': 16311,
#   'reverted': 14563,
#   'rumored': 14902,
#   'meanest': 10867,
#   'recording': 14084,
#   'floral': 6805,
#   'abroad': 399,
#   'loans': 10299,
#   'insect': 8902,
#   'lease': 10010,
#   'listings': 10255,
#   'squinting': 16587,
#   'krueger': 9775,
#   'endeavored': 5927,
#   'eighty': 5765,
#   'roam': 14700,
#   'solace': 16249,
#   'cartoonist': 2982,
#   'bug': 2579,
#   'objective': 11935,
#   'real': 13984,
#   'outfit': 12214,
#   'cracker': 4266,
#   '21,000': 191,
#   'surpassed': 17171,
#   'waves': 19188,
#   'fascination': 6423,
#   'watermelon': 19175,
#   'polishing': 13112,
#   'announcer': 999,
#   'conquer': 3959,
#   'bernadette': 1903,
#   'edwards': 5733,
#   'scraps': 15242,
#   'representative': 14397,
#   'afford': 651,
#   'wow': 19699,
#   'arrow': 1224,
#   'molested': 11282,
#   '34': 233,
#   'iraq': 9083,
#   'alzheimer': 875,
#   'quarterback': 13730,
#   'jerked': 9282,
#   'letting': 10102,
#   'hurried': 8561,
#   'discovering': 5170,
#   'assembly': 1289,
#   'acupuncture': 530,
#   'doubtful': 5414,
#   'elbowed': 5777,
#   'bennett': 1888,
#   'further': 7188,
#   'delivery': 4837,
#   'baseball': 1667,
#   'identification': 8623,
#   'shallow': 15540,
#   'rise': 14672,
#   'jackpot': 9159,
#   'dashing': 4638,
#   'lovely': 10420,
#   'delaney': 4809,
#   'beaches': 1728,
#   'searching': 15313,
#   'poisoned': 13087,
#   'deliberating': 4820,
#   'indefinitely': 8773,
#   'bands': 1599,
#   'baseman': 1669,
#   'fatigue': 6445,
#   'kaylee': 9555,
#   'stars': 16675,
#   'translator': 18155,
#   'assembling': 1288,
#   'cons': 3963,
#   'expose': 6280,
#   'chastened': 3200,
#   'detector': 4976,
#   'bark': 1643,
#   'apology': 1080,
#   'shoplift': 15684,
#   'illness': 8658,
#   'jorge': 9397,
#   'negative': 11634,
#   'lotions': 10396,
#   'stellar': 16740,
#   'flip-flops': 6777,
#   'enter': 5982,
#   'scenario': 15153,
#   'formations': 6952,
#   'i': 8600,
#   'ryan': 14937,
#   'rubix': 14870,
#   'difficulties': 5064,
#   'nh': 11714,
#   'decatur': 4719,
#   'signature': 15809,
#   'bake': 1552,
#   'carts': 2986,
#   'unfaithful': 18558,
#   'clive': 3551,
#   'look': 10357,
#   'workload': 19658,
#   'families': 6386,
#   'neil': 11652,
#   'baby': 1490,
#   'rodriguez': 14751,
#   'lochte': 10314,
#   'sabotage': 14945,
#   'schoolyard': 15180,
#   'jagged': 9172,
#   'stud': 16952,
#   'network': 11688,
#   'diced': 5042,
#   'portfolio': 13185,
#   'obedient': 11925,
#   'ale': 769,
#   'esme': 6075,
#   'required': 14414,
#   'advisor': 634,
#   'drive-in': 5517,
#   'pace': 12326,
#   'unnecessary': 18622,
#   'lead': 9976,
#   'clawed': 3489,
#   'footwear': 6900,
#   'reheated': 14222,
#   'withdrawals': 19567,
#   'frustratingly': 7132,
#   'elder': 5779,
#   'angrier': 964,
#   'unbearably': 18497,
#   'imported': 8705,
#   'surprisingly': 17176,
#   'dottoe': 5406,
#   'prescribe': 13345,
#   'x-box': 19770,
#   'give': 7430,
#   'defy': 4799,
#   'encyclopedia': 5921,
#   'kidneys': 9636,
#   'snowball': 16183,
#   'ties': 17847,
#   '2nd': 216,
#   'attempt': 1354,
#   'nonsense': 11816,
#   'graduate': 7592,
#   'lifeguards': 10148,
#   'ian': 8603,
#   'foresight': 6924,
#   'cello': 3096,
#   'natasha': 11579,
#   'mona': 11294,
#   'lamarrio': 9841,
#   'checking': 3226,
#   'elenora': 5804,
#   'referral': 14144,
#   'julia': 9452,
#   'allergy': 817,
#   'kacie': 9492,
#   'dd': 4672,
#   'marissa': 10724,
#   'bookmark': 2232,
#   'carseat': 2972,
#   'gofundme': 7515,
#   'sample': 15020,
#   'tamara': 17426,
#   'fans': 6398,
#   'phenomenal': 12789,
#   'manchester': 10627,
#   'tribe': 18223,
#   'basically': 1673,
#   'tutorial': 18380,
#   'goat': 7501,
#   'lynette': 10503,
#   'respiratory': 14475,
#   'counters': 4210,
#   'easiest': 5681,
#   'marshall': 10761,
#   'january': 9215,
#   'slurring': 16061,
#   'droppings': 5537,
#   'lumberjack': 10470,
#   'fe': 6467,
#   'bracing': 2339,
#   'repertoire': 14373,
#   'album': 762,
#   'artie': 1235,
#   'obey': 11928,
#   'betty': 1935,
#   'campaigning': 2807,
#   'promised': 13510,
#   'write-up': 19742,
#   'thirties': 17749,
#   'crane': 4287,
#   'cheekbones': 3237,
#   'room': 14795,
#   'softly': 16244,
#   'finch': 6630,
#   'cleared': 3505,
#   'benji': 1885,
#   'keychain': 9615,
#   'spotlight': 16510,
#   'italy': 9131,
#   'chopped': 3348,
#   'boardwalk': 2168,
#   'weaved': 19216,
#   'smoothly': 16112,
#   'dune': 5602,
#   'gifts': 7395,
#   '30.': 222,
#   'bpl': 2332,
#   'selma': 15411,
#   'dissect': 5246,
#   'marriages': 10753,
#   'collections': 3692,
#   'lobster': 10304,
#   'infections': 8824,
#   'jerod': 9286,
#   'repeatedly': 14368,
#   'dirk': 5125,
#   'clubhouse': 3590,
#   'raps': 13912,
#   'did': 5047,
#   'apologize': 1076,
#   'bodyweight': 2187,
#   'nobles': 11793,
#   'enamored': 5908,
#   'cranked': 4290,
#   'address': 557,
#   'sully': 17079,
#   'voles': 19004,
#   'casually': 3014,
#   'thirtieth': 17750,
#   'lilian': 10186,
#   'seattle': 15333,
#   'customized': 4525,
#   'doorknobs': 5382,
#   'aware': 1460,
#   'understood': 18535,
#   'food': 6881,
#   'songwriter': 16290,
#   'bushy': 2672,
#   'dava': 4647,
#   'cove': 4238,
#   'paced': 12327,
#   'damion': 4569,
#   'suspected': 17201,
#   'calves': 2785,
#   'camping': 2815,
#   'feeling': 6498,
#   'denied': 4865,
#   'cave': 3058,
#   'outstretched': 12242,
#   'east': 5683,
#   'getaway': 7375,
#   'ghia': 7380,
#   'opponents': 12103,
#   'windpipe': 19496,
#   'are': 1166,
#   'pointe': 13076,
#   'chandelier': 3152,
#   'drinked': 5509,
#   'charts': 3195,
#   'zaddyfracks': 19922,
#   'bathroom': 1693,
#   'interviews': 9017,
#   'elf': 5813,
#   'hyper': 8588,
#   'jockey': 9346,
#   'entrepreneur': 6006,
#   'banks': 1612,
#   'bedside': 1788,
#   'breaks': 2407,
#   'janitor': 9213,
#   'brii': 2468,
#   'downtown': 5438,
#   'situation': 15886,
#   'ping': 12894,
#   'eagles': 5651,
#   'roberto': 14721,
#   'miller': 11108,
#   'knick': 9716,
#   'owe': 12306,
#   'brains': 2354,
#   'harp': 8019,
#   'kacey': 9491,
#   'lunchbox': 10476,
#   'surfers': 17162,
#   'blu': 2144,
#   'tab': 17351,
#   'quicksand': 13754,
#   'certified': 3122,
#   'fare': 6404,
#   'begging': 1816,
#   'houses': 8477,
#   'cuddling': 4463,
#   'undercover': 18520,
#   'turbo': 18357,
#   'auditions': 1395,
#   'batters': 1704,
#   'indians': 8781,
#   'nigel': 11749,
#   'locking': 10321,
#   'katrina': 9546,
#   'fifteenth': 6578,
#   'coraline': 4131,
#   'ministers': 11148,
#   'rhuigi': 14593,
#   'travel': 18173,
#   'rage': 13827,
#   'booked': 2229,
#   'cancer-free': 2833,
#   'nagged': 11539,
#   'vogue': 18996,
#   'cynthia': 4543,
#   'wiping': 19540,
#   'superintendent': 17120,
#   'approached': 1134,
#   'braids': 2352,
#   'sex': 15513,
#   '16th': 83,
#   'xenophobia': 19782,
#   'angelica': 954,
#   'buzzing': 2710,
#   'cocktail': 3643,
#   'mighty': 11078,
#   'economy': 5705,
#   'peasant': 12617,
#   'doing': 5334,
#   'pound': 13243,
#   'dismiss': 5205,
#   'unmarked': 18618,
#   'specific': 16402,
#   'round': 14833,
#   'play-offs': 12984,
#   'workmen': 19661,
#   'dvr': 5628,
#   'shaving': 15586,
#   'pia': 12828,
#   'rover': 14844,
#   'glint': 7464,
#   'glasses': 7450,
#   'artistic': 1240,
#   'ever': 6135,
#   'conceive': 3869,
#   'says': 15107,
#   'gagged': 7213,
#   'harvesting': 8033,
#   'leader': 9977,
#   'honorable': 8381,
#   'reliable': 14264,
#   'pronounced': 13523,
#   'grumbled': 7776,
#   'inventing': 9047,
#   'bravest': 2385,
#   'bidder': 1961,
#   'instilled': 8939,
#   'beau': 1762,
#   'smoking': 16102,
#   'jabbed': 9151,
#   'helga': 8155,
#   'honked': 8376,
#   'interruption': 9005,
#   '40.': 248,
#   'rhoda': 14591,
#   'safest': 14966,
#   'smoother': 16108,
#   'served': 15471,
#   'marg': 10692,
#   'vasquez': 18825,
#   'ignoring': 8641,
#   'ding': 5098,
#   'walruses': 19098,
#   'cuba': 4451,
#   'pandas': 12413,
#   'delicate': 4823,
#   'tomatoes': 17974,
#   'inning': 8886,
#   'fabric': 6335,
#   'unprofessional': 18637,
#   'scientific': 15186,
#   'hernandez': 8201,
#   '24/7': 202,
#   'naps': 11566,
#   'colton': 3723,
#   'hispanic': 8286,
#   'sheena': 15599,
#   'tablet': 17358,
#   'chowder': 3364,
#   'hairbrush': 7888,
#   'greeting': 7687,
#   'merry-go-round': 10997,
#   'pitbull': 12923,
#   'bff': 1946,
#   'nacho': 11533,
#   'guidance': 7798,
#   'fingers': 6642,
#   'ruins': 14885,
#   'congratulated': 3944,
#   'ragged': 13829,
#   'sight': 15798,
#   'brandi': 2368,
#   'hairspray': 7896,
#   'colon': 3711,
#   'reduce': 14123,
#   'desk': 4943,
#   'fido': 6569,
#   'beta': 1924,
#   'sing': 15849,
#   '25th': 207,
#   'chase': 3196,
#   'grazed': 7662,
#   'allowance': 832,
#   '1999': 141,
#   'nachos': 11534,
#   'longterm': 10355,
#   'lurking': 10487,
#   'sylvie': 17328,
#   'describe': 4920,
#   'christine': 3372,
#   'cottage': 4187,
#   'rows': 14852,
#   'cruise': 4419,
#   'arthritis': 1229,
#   'stunted': 16978,
#   'flounder': 6813,
#   'ravens': 13947,
#   'grounds': 7750,
#   'strawberries': 16872,
#   'nursing': 11895,
#   'coins': 3663,
#   'chops': 3351,
#   'esmeralda': 6076,
#   'clues': 3595,
#   'flex': 6759,
#   'wrecked': 19718,
#   'middling': 11070,
#   'scarecrow': 15131,
#   'jocelyn': 9344,
#   'clocks': 3555,
#   'distracted': 5258,
#   'goes': 7514,
#   'marcellus': 10680,
#   'sculpt': 15284,
#   'disguised': 5185,
#   'slacker': 15964,
#   'reopened': 14354,
#   'matters': 10824,
#   'disregarded': 5237,
#   'raphael': 13905,
#   'autistic': 1416,
#   'ballroom': 1578,
#   'atlanta': 1333,
#   'pockets': 13061,
#   'riki': 14647,
#   'pledge': 13021,
#   'pizzas': 12939,
#   'lazy': 9973,
#   'pride': 13404,
#   'patrolled': 12545,
#   'angrily': 965,
#   'arson': 1226,
#   'forearm': 6912,
#   'related': 14242,
#   'great-aunt': 7668,
#   'investigating': 9057,
#   'brain': 2353,
#   'photoshopped': 12819,
#   'buret': 2640,
#   'odor': 11988,
#   'mortified': 11365,
#   'accent': 425,
#   'connection': 3952,
#   'amidst': 907,
#   '3000': 226,
#   'lita': 10259,
#   'jackson': 9161,
#   'muttered': 11511,
#   'nico': 11740,
#   'pedaling': 12626,
#   'spinners': 16453,
#   'rambler': 13871,
#   'fervently': 6542,
#   'botanist': 2273,
#   'lidia': 10139,
#   'airplanes': 730,
#   'announce': 995,
#   'thad': 17680,
#   'adulthood': 613,
#   'wasteful': 19160,
#   'immigrant': 8684,
#   'doorway': 5386,
#   'x-ray': 19772,
#   'leasing': 10015,
#   'rumble': 14894,
#   'wiped': 19536,
#   'boss': 2266,
#   'vocal': 18992,
#   'geb': 7303,
#   'trims': 18243,
#   'batted': 1700,
#   'bluegrass': 2150,
#   'adelyn': 563,
#   'hypnosis': 8591,
#   'categories': 3028,
#   'audiences': 1386,
#   'benjy': 1886,
#   'nicknamed': 11737,
#   'ideal': 8620,
#   'brewers': 2433,
#   'hitler': 8299,
#   'expedition': 6239,
#   'sanitizer': 15052,
#   'newborn': 11700,
#   'encore': 5913,
#   'clearer': 3506,
#   'bunker': 2633,
#   'allies': 826,
#   'investing': 9060,
#   'juggled': 9441,
#   'inflexible': 8837,
#   'maeva': 10542,
#   'mousse': 11408,
#   'customary': 4521,
#   'remy': 14324,
#   'incident': 8748,
#   'assist': 1299,
#   'sweat': 17248,
#   'scour': 15220,
#   'ethical': 6103,
#   'hangers': 7972,
#   'wasp': 19156,
#   'whoever': 19390,
#   'pax': 12577,
#   'inbox': 8740,
#   'accents': 426,
#   'slippery': 16025,
#   'extracted': 6304,
#   'elvis': 5850,
#   'rory': 14810,
#   'awareness': 1461,
#   'multiple': 11462,
#   'aroma': 1202,
#   'signed': 15811,
#   'delta': 4840,
#   'soundtrack': 16334,
#   'outlet': 12222,
#   'acquired': 501,
#   '5000': 277,
#   'scary': 15145,
#   'punishment': 13655,
#   'partial': 12476,
#   'cans': 2858,
#   'kellan': 9577,
#   'jasmine': 9223,
#   'credits': 4336,
#   'riding': 14632,
#   'cutthroat': 4533,
#   'involve': 9073,
#   'bride': 2448,
#   'ante': 1021,
#   'carrier': 2964,
#   'sofie': 16238,
#   'dvd': 5626,
#   'maggy': 10550,
#   'beth': 1925,
#   'award': 1456,
#   'password': 12512,
#   'hikers': 8252,
#   'rink': 14659,
#   'hacking': 7878,
#   'tip-top': 17907,
#   'hammer': 7924,
#   'clue': 3593,
#   ...}}
